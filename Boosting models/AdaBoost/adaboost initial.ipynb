# %%
pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in a:\anacondainstall\envs\tensorflow\lib\site-packages (1.2.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.1.post1-cp39-cp39-win_amd64.whl (10.6 MB)
#      --------------------------------------- 10.6/10.6 MB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.2.0 in a:\anacondainstall\envs\tensorflow\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.6.0 in a:\anacondainstall\envs\tensorflow\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in a:\anacondainstall\envs\tensorflow\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in a:\anacondainstall\envs\tensorflow\lib\site-packages (from scikit-learn) (3.1.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'A:\\Anacondainstall\\envs\\tensorflow\\Lib\\site-packages\\~klearn\\.libs\\msvcp140.dll'
# Consider using the `--user` option or check the permissions.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('Combined.csv',low_memory=False)

# %%
df
# Out:
#          Unnamed: 0  Seq       Dur   RunTime      Mean       Sum       Min  \
# 0                 0    1  0.000000  0.000000  0.000000  0.000000  0.000000
# 1                 1    2  0.000000  0.000000  0.000000  0.000000  0.000000
# 2                 2    3  4.998020  4.998020  4.998020  4.998020  4.998020
# 3                 3    4  4.998037  4.998037  4.998037  4.998037  4.998037
# 4                 4    5  4.999453  4.999453  4.999453  4.999453  4.999453
# ...             ...  ...       ...       ...       ...       ...       ...
# 1215885      487569    1  0.000000  0.000000  0.000000  0.000000  0.000000
# 1215886      487570    3  0.235607  0.235607  0.235607  0.235607  0.235607
# 1215887      487571  764  0.099927  0.099927  0.099927  0.099927  0.099927
# 1215888      487572    3  1.307852  1.307852  1.307852  1.307852  1.307852
# 1215889      487573    1  0.476803  0.476803  0.476803  0.476803  0.476803
#
#               Max Proto   sTos  ...   sVid   dVid    SrcTCPBase    DstTCPBase  \
# 0        0.000000  icmp    0.0  ...    NaN    NaN           NaN           NaN
# 1        0.000000  icmp    0.0  ...    NaN    NaN           NaN           NaN
# 2        4.998020   udp    0.0  ...    NaN    NaN           NaN           NaN
# 3        4.998037   udp    0.0  ...    NaN    NaN           NaN           NaN
# 4        4.999453   udp    0.0  ...    NaN    NaN           NaN           NaN
# ...           ...   ...    ...  ...    ...    ...           ...           ...
# 1215885  0.000000  sctp  186.0  ...  610.0    NaN           NaN           NaN
# 1215886  0.235607  sctp  186.0  ...    NaN  610.0           NaN           NaN
# 1215887  0.099927   tcp    0.0  ...    NaN    NaN  2.237373e+09  1.983280e+09
# 1215888  1.307852  sctp  186.0  ...    NaN  610.0           NaN           NaN
# 1215889  0.476803  sctp  186.0  ...  610.0    NaN           NaN           NaN
#
#          TcpRtt  SynAck  AckDat   Label  Attack Type  Attack Tool
# 0           0.0     0.0     0.0  Benign       Benign       Benign
# 1           0.0     0.0     0.0  Benign       Benign       Benign
# 2           0.0     0.0     0.0  Benign       Benign       Benign
# 3           0.0     0.0     0.0  Benign       Benign       Benign
# 4           0.0     0.0     0.0  Benign       Benign       Benign
# ...         ...     ...     ...     ...          ...          ...
# 1215885     0.0     0.0     0.0  Benign       Benign       Benign
# 1215886     0.0     0.0     0.0  Benign       Benign       Benign
# 1215887     0.0     0.0     0.0  Benign       Benign       Benign
# 1215888     0.0     0.0     0.0  Benign       Benign       Benign
# 1215889     0.0     0.0     0.0  Benign       Benign       Benign
#
# [1215890 rows x 52 columns]

# %%
df.drop('Unnamed: 0',axis = 1 ,inplace = True)

# %%
df.columns
# Out:
# Index(['Seq', 'Dur', 'RunTime', 'Mean', 'Sum', 'Min', 'Max', 'Proto', 'sTos',
#        'dTos', 'sDSb', 'dDSb', 'sTtl', 'dTtl', 'sHops', 'dHops', 'Cause',
#        'TotPkts', 'SrcPkts', 'DstPkts', 'TotBytes', 'SrcBytes', 'DstBytes',
#        'Offset', 'sMeanPktSz', 'dMeanPktSz', 'Load', 'SrcLoad', 'DstLoad',
#        'Loss', 'SrcLoss', 'DstLoss', 'pLoss', 'SrcGap', 'DstGap', 'Rate',
#        'SrcRate', 'DstRate', 'State', 'SrcWin', 'DstWin', 'sVid', 'dVid',
#        'SrcTCPBase', 'DstTCPBase', 'TcpRtt', 'SynAck', 'AckDat', 'Label',
#        'Attack Type', 'Attack Tool'],
#       dtype='object')

# %%
X = df.copy()
X.drop('Attack Type',inplace = True,axis = 1)
y = df[['Attack Type']]

# %%
cat_var = [key for key in dict(X.dtypes)
             if dict(X.dtypes)[key] in ['object'] ]

print(cat_var)
# Out:
# ['Proto', 'sDSb', 'dDSb', 'Cause', 'State', 'Label', 'Attack Tool']

# %%
ohe = OneHotEncoder(handle_unknown='ignore',sparse=False)
Xcat = pd.DataFrame(ohe.fit_transform(X[cat_var]),columns=ohe.get_feature_names_out(),index=X.index)
X = pd.concat([X,Xcat],axis=1)
X.drop(labels=cat_var,axis=1,inplace=True)
X.sample(5)
# Out:
# A:\Anacondainstall\envs\tensorflow\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#           Seq       Dur   RunTime      Mean       Sum       Min       Max  \
# 869828  48023  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 786904   9535  2.847591  2.847591  2.847591  2.847591  2.847591  2.847591
# 891880  57789  2.570767  2.570767  2.570767  2.570767  2.570767  2.570767
# 656973  37932  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 176845   9380  4.553308  4.553308  4.553308  4.553308  4.553308  4.553308
#
#         sTos  dTos  sTtl  ...  State_TST  State_URP  Label_Benign  \
# 869828   0.0   NaN  63.0  ...        0.0        0.0           0.0
# 786904   0.0   NaN  63.0  ...        0.0        0.0           0.0
# 891880   0.0   NaN  63.0  ...        0.0        0.0           0.0
# 656973   0.0   NaN  58.0  ...        0.0        0.0           1.0
# 176845   0.0   NaN  63.0  ...        0.0        0.0           0.0
#
#         Label_Malicious  Attack Tool_Benign  Attack Tool_Goldeneye  \
# 869828              1.0                 0.0                    0.0
# 786904              1.0                 0.0                    0.0
# 891880              1.0                 0.0                    0.0
# 656973              0.0                 1.0                    0.0
# 176845              1.0                 0.0                    0.0
#
#         Attack Tool_Hping3  Attack Tool_Nmap  Attack Tool_Slowloris  \
# 869828                 1.0               0.0                    0.0
# 786904                 1.0               0.0                    0.0
# 891880                 1.0               0.0                    0.0
# 656973                 0.0               0.0                    0.0
# 176845                 1.0               0.0                    0.0
#
#         Attack Tool_Torshammer
# 869828                     0.0
# 786904                     0.0
# 891880                     0.0
# 656973                     0.0
# 176845                     0.0
#
# [5 rows x 93 columns]

# %%
columns_with_null = df.columns[df.isnull().any()]

# %%
df[columns_with_null].isnull().sum()
# Out:
# sTos              214
# dTos           943067
# sDSb              214
# dDSb           943067
# sTtl              214
# dTtl           943067
# sHops             214
# dHops          943067
# SrcGap         937219
# DstGap         937219
# SrcWin         973470
# DstWin        1038812
# sVid          1101319
# dVid          1213881
# SrcTCPBase     937219
# DstTCPBase     985843
# dtype: int64

# %%
df.fillna(0,inplace = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
model = AdaBoostClassifier(n_estimators = 1000)

# %%
X_train.isnull().sum().sort_values(ascending=False)
X_train.fillna(0,inplace = True)
# Out:
# Seq                       0
# sDSb_cs4                  0
# dDSb_cs4                  0
# dDSb_cs1                  0
# dDSb_cs0                  0
#                          ..
# SrcGap                    0
# pLoss                     0
# DstLoss                   0
# SrcLoss                   0
# Attack Tool_Torshammer    0
# Length: 93, dtype: int64

# %%
# Record the start time
start_time = time.time()

# %%
model.fit(X_train,y_train)
# Out:
# A:\Anacondainstall\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostClassifier(n_estimators=1000)

# %%
# Record the end time
end_time = time.time()

# %%
training_time = end_time - start_time
print("Training time:", training_time, "seconds")

# %%
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [85], line 1
# ----> 1 y_pred = model.predict(X_test)
#
# File A:\Anacondainstall\envs\tensorflow\lib\site-packages\sklearn\ensemble\_weight_boosting.py:700, in AdaBoostClassifier.predict(self, X)
#     683 def predict(self, X):
#     684     """Predict classes for X.
#     685
#     686     The predicted class of an input sample is computed as the weighted mean
#    (...)
#     698         The predicted classes.
#     699     """
# --> 700     pred = self.decision_function(X)
#     702     if self.n_classes_ == 2:
#     703         return self.classes_.take(pred > 0, axis=0)
#
# File A:\Anacondainstall\envs\tensorflow\lib\site-packages\sklearn\ensemble\_weight_boosting.py:761, in AdaBoostClassifier.decision_function(self, X)
#     742 """Compute the decision function of ``X``.
#     743
#     744 Parameters
#    (...)
#     758     class in ``classes_``, respectively.
#     759 """
#     760 check_is_fitted(self)
# --> 761 X = self._check_X(X)
#     763 n_classes = self.n_classes_
#     764 classes = self.classes_[:, np.newaxis]
#
# File A:\Anacondainstall\envs\tensorflow\lib\site-packages\sklearn\ensemble\_weight_boosting.py:94, in BaseWeightBoosting._check_X(self, X)
#      92 def _check_X(self, X):
#      93     # Only called to validate X in non-fit methods, therefore reset=False
# ---> 94     return self._validate_data(
#      95         X,
#      96         accept_sparse=["csr", "csc"],
#      97         ensure_2d=True,
#      98         allow_nd=True,
#      99         dtype=None,
#     100         reset=False,
#     101     )
#
# File A:\Anacondainstall\envs\tensorflow\lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563     raise ValueError("Validation should be done on X, y or both.")
#     564 elif not no_val_X and no_val_y:
# --> 565     X = check_array(X, input_name="X", **check_params)
#     566     out = X
#     567 elif no_val_X and not no_val_y:
#
# File A:\Anacondainstall\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File A:\Anacondainstall\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# AdaBoostClassifier does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
#classification Report
report = classification_report(y_test, y_pred)
